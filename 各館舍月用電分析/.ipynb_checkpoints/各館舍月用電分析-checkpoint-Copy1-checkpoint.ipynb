# %%
# %matplotlib
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
file = open('./工程一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
df.columns
# Out:
# Index(['﻿時  間', '區 域', '館 舍 別', '迴 路 別', '用電別', '用電量(單位:度)'], dtype='object')

# %%
#北區
#工程一館月用電

file = open('./工程一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['﻿時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'﻿時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區工程一館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區工程一館月用電比')

# %%
#北區
#工程二館月用電

file = open('./工程二館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['﻿時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'﻿時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區工程二館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()

newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區工程二館月用電比')

# %%
#工程三館月用電

file = open('./工程三館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_工程三館月用電')

newdf2 = newdf
print (newdf2.Usage)
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
# newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
# df2new_gpby = newdf2.groupby(['Month'])
# df2new_gpby.mean().plot.bar(color='#9900FF')
# matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# savefig('Fig_工程三館月用電比')

# %%
#工程四館月用電

file = open('./工程四館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_工程四館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_工程四館月用電比')

# %%
#工程五館月用電

file = open('./工程五館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_工程五館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_工程五館月用電比')

# %%
#工程六館月用電

file = open('./工程六館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_工程六館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_工程六館月用電比')

# %%
#北區
#科學一館月用電

file = open('./科學一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區科學一館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區科學一館月用電比')

# %%
#北區
#科學二館月用電

file = open('./科學二館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區科學二館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區科學二館月用電比')

# %%
#北區
#基礎大樓月用電

file = open('./基礎大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區基礎大樓月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區基礎大樓月用電比')

# %%
#北區
#人社一館月用電

file = open('./人社一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區人社一館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區人社一館月用電比')

# %%
#北區
#人社二館月用電

file = open('./人社二館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區人社二館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區人社二館月用電比')

# %%
#北區
#管理一館月用電

file = open('./管理一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區管理一館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區管理一館月用電比')

# %%
#管理二館月用電

file = open('./管理二館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_管理二館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_管理二館月用電比')

# %%
#綜合一館月用電

file = open('./綜合一館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_綜合一館月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_綜合一館月用電比')

# %%
#交映樓月用電

file = open('./交映樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#北區
#光電大樓月用電

file = open('./光電大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區光電大樓月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區光電大樓月用電比')

# %%
#北區
#電資大樓月用電

file = open('./電資大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區電資大樓月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區電資大樓月用電比')

# %%
#資訊館月用電

file = open('./資訊館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#資訊館(南區)月用電

file = open('./資訊館(南區)_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#中正堂月用電

file = open('./中正堂_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#服務大樓月用電

file = open('./服務大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#北區
#行政大樓月用電

file = open('./行政大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區行政大樓月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區行政大樓月用電比')

# %%
#活動中心(含一餐)月用電

file = open('./活動中心_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#綜合球館月用電

file = open('./綜合球館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#游泳館月用電

file = open('./游泳館_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#第二餐廳月用電

file = open('./第二餐廳_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#七舍_八舍月用電

file = open('./七舍_八舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#九舍月用電

file = open('./九舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#十舍月用電

file = open('./十舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#十一舍月用電

file = open('./十一舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#十二舍月用電

file = open('./十二舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#十三舍(含1F便利商店)月用電

file = open('./十三舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#研一舍月用電

file = open('./研一舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#研二舍月用電

file = open('./研二舍_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#竹軒月用電

file = open('./竹軒_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

# %%
#北區
#環保大樓月用電

file = open('./環保大樓_20160901_20170831.csv', encoding = 'utf8')
df = pd.read_csv(file)
newdf= df[['時  間','用電量(單位:度)']]
newdf = newdf.rename(index=str, columns={'時  間':"Month",'用電量(單位:度)':"Usage"}) 
dfnew_gpby = newdf.groupby(['Month'])
dfnew_gpby.mean().plot.bar()
matplotlib.pyplot.title('Monthly electricity usage')

savefig('Fig_北區環保大樓月用電')

newdf2 = newdf
newdf2['Usage'] = newdf2['Usage'] / newdf2['Usage'].mean()
newdf2 = newdf2.rename(index=str, columns={'Usage':"Ratio"})
df2new_gpby = newdf2.groupby(['Month'])
df2new_gpby.mean().plot.bar(color='#9900FF')
matplotlib.pyplot.title('The Ratio of Monthly electricity usage to Mean value')

savefig('Fig_北區環保大樓月用電比')

# %%
#savefig('各館舍月用電分析圖(月用電_月用電比)')
# ?savefig()
