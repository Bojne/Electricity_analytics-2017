# %%
import pandas as pd
import numpy as np
# %matplotlib 
# %pylab inline
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
#畫圖設定
font = {    'size'   : 18}
pylab.rcParams['figure.figsize'] = (20, 8) #Make figure larger.
matplotlib.rc('font', **font)

# %%
df = pd.read_csv('./data/北區所有＿扣掉大怪獸_英文_20160901_20170831.csv')
df.head()
# Out:
#       Date   Area       bd_name                  loop  \
# 0  2017/08  North  Tien_gia_bin  主迴路
# 1  2017/08  North            SC  主迴路
# 2  2017/08  North          EECS  主迴路
# 3  2017/08  North            SB  主迴路
# 4  2017/08  North  DinningHall2  主迴路
#
#                        Type     Usage
# 0   Teach                    421187.8
# 1   Teach                    322267.0
# 2   Teach                    305416.0
# 3   Teach                    183416.0
# 4  Rented                    113984.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 6 columns):
# Date       712 non-null object
# Area       712 non-null object
# bd_name    712 non-null object
# loop       712 non-null object
# Type       712 non-null object
# Usage      712 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 33.5+ KB
# None

# %%
#檢查有沒有缺值
#dinninghall2,ActivityCenter  好像有缺
df.bd_name.value_counts()
# Out:
# DinningHall2                 178
# ActivityCenter               114
# EECS                          48
# Gym                           36
# CCAuditorium                  36
# SD10                          24
# Info(North)                   24
# SB                            12
# GraduateDorm1                 12
# First_dorm                    12
# HABuilding2                   12
# HA1                           12
# SC                            12
# EnvProtect_bd                 12
# Tien_gia_bin                  12
# SD11                          12
# Engineer2                     12
# Engineer1                     12
# Motocycle                     12
# Admin_bd                      12
# Swim                          12
# Chu-HsuanFemale               12
# SA                            12
# Badminton                     12
# GraduateStudentDormitory1     12
# WasteWater                    12
# Manegement1                   12
# StudentDormitory9             12
# Name: bd_name, dtype: int64

# %%
df[df.Usage ==0] #找哪些
# Out:
#         Date   Area         bd_name                  loop  \
# 53   2017/08  North        Admin_bd  主迴路
# 54   2017/08  North  ActivityCenter  空調R
# 55   2017/08  North     Info(North)  主迴路
# 56   2017/08  North       Badminton  主迴路
# 57   2017/08  North      WasteWater  主迴路
# 58   2017/08  North            SD10  學生交誼廳
# 59   2017/08  North    DinningHall2              2F水果部P動力
# 116  2017/07  North  ActivityCenter  空調R
# 117  2017/07  North     Info(North)  主迴路
# 118  2017/07  North       Badminton  主迴路
# 119  2017/07  North      WasteWater  主迴路
# 176  2017/06  North  ActivityCenter  空調R
# 177  2017/06  North       Badminton  主迴路
# 178  2017/06  North      WasteWater  主迴路
# 179  2017/06  North    DinningHall2              2F水果部P動力
# 237  2017/05  North  ActivityCenter  空調R
# 238  2017/05  North      WasteWater  主迴路
# 239  2017/05  North    DinningHall2              2F水果部P動力
# 297  2017/04  North  ActivityCenter  空調R
# 298  2017/04  North     Info(North)  主迴路
# 299  2017/04  North    DinningHall2              2F水果部P動力
# 356  2017/03  North     Info(North)  主迴路
# 357  2017/03  North    DinningHall2              2F水果部P動力
# 415  2017/02  North     Info(North)  主迴路
# 416  2017/02  North    DinningHall2              2F水果部P動力
# 474  2017/01  North    DinningHall2              2F水果部P動力
# 530  2016/12  North     Info(North)  主迴路
# 531  2016/12  North    Tien_gia_bin  主迴路
# 532  2016/12  North   EnvProtect_bd  主迴路
# 533  2016/12  North    DinningHall2              2F水果部P動力
# 591  2016/11  North     Info(North)  主迴路
# 592  2016/11  North    DinningHall2              2F水果部P動力
# 652  2016/10  North    DinningHall2              2F水果部P動力
# 709  2016/09  North  ActivityCenter  主迴路
# 710  2016/09  North     Info(North)  主迴路
# 711  2016/09  North    DinningHall2              2F水果部P動力
#
#                          Type  Usage
# 53    Admin                      0.0
# 54    Admin                      0.0
# 55    Admin                      0.0
# 56    Admin                      0.0
# 57    Admin                      0.0
# 58     Dorm                      0.0
# 59   Rented                      0.0
# 116   Admin                      0.0
# 117   Admin                      0.0
# 118   Admin                      0.0
# 119   Admin                      0.0
# 176   Admin                      0.0
# 177   Admin                      0.0
# 178   Admin                      0.0
# 179  Rented                      0.0
# 237   Admin                      0.0
# 238   Admin                      0.0
# 239  Rented                      0.0
# 297   Admin                      0.0
# 298   Admin                      0.0
# 299  Rented                      0.0
# 356   Admin                      0.0
# 357  Rented                      0.0
# 415   Admin                      0.0
# 416  Rented                      0.0
# 474  Rented                      0.0
# 530   Admin                      0.0
# 531   Teach                      0.0
# 532   Teach                      0.0
# 533  Rented                      0.0
# 591   Admin                      0.0
# 592  Rented                      0.0
# 652  Rented                      0.0
# 709   Admin                      0.0
# 710   Admin                      0.0
# 711  Rented                      0.0

# %%
#每個月的用電量
#print(df1.groupby('bd_name').mean().plot.bar()) #沒排序版本
print(df.groupby('bd_name').mean().sort_values('Usage')['Usage'].plot.bar())
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
# Out:
#   File "<ipython-input-12-151b05c89c10>", line 1
#     print(df.groupby('bd_name').mean().sort_values('Usage')['Usage'].nlargest(n=6)
#                                                                                   ^
# SyntaxError: unexpected EOF while parsing
